# %%
import chart_studio.plotly as py

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.7.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot

# %%
init_notebook_mode(connected= True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0   0.855845  0.304247  0.148263  0.440381
# 1   0.991168 -0.414742 -0.855016  0.656566
# 2   1.736655 -0.322684 -0.660755 -0.640801
# 3   0.812633  0.444356  0.441561  0.302533
# 4  -0.984177  3.206725 -0.544054 -2.045357
# ..       ...       ...       ...       ...
# 95  0.686441  1.777911 -0.898918  0.252687
# 96  0.692718  1.028938 -0.059923  0.017716
# 97 -0.460625 -0.881843 -1.472172  1.077870
# 98  1.324927  1.153510 -0.448922  1.917004
# 99  0.286166 -0.796863  0.430403  0.776166
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="7311d716-1958-4bf3-905b-efc7116fabca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7311d716-1958-4bf3-905b-efc7116fabca")) {
#                     Plotly.newPlot(
#                         '7311d716-1958-4bf3-905b-efc7116fabca',
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>
#
#
#             <div id="fcea9bb4-22ef-4054-b13b-e1a6fb21f7b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fcea9bb4-22ef-4054-b13b-e1a6fb21f7b0")) {
#                     Plotly.newPlot(
#                         'fcea9bb4-22ef-4054-b13b-e1a6fb21f7b0',
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers', size = 5)
# Out:
# <div>
#
#
#             <div id="057b0db4-b43b-4a91-9b65-b5a1910cdb5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("057b0db4-b43b-4a91-9b65-b5a1910cdb5b")) {
#                     Plotly.newPlot(
#                         '057b0db4-b43b-4a91-9b65-b5a1910cdb5b',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="e9ff2766-e82d-438c-bc75-5803cbc1bc64" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9ff2766-e82d-438c-bc75-5803cbc1bc64")) {
#                     Plotly.newPlot(
#                         'e9ff2766-e82d-438c-bc75-5803cbc1bc64',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="032dbcdb-3a13-4fc3-8596-15503c56ffbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("032dbcdb-3a13-4fc3-8596-15503c56ffbd")) {
#                     Plotly.newPlot(
#                         '032dbcdb-3a13-4fc3-8596-15503c56ffbd',
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="817b8423-ef63-4772-99d7-1cca6e5d40a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("817b8423-ef63-4772-99d7-1cca6e5d40a3")) {
#                     Plotly.newPlot(
#                         '817b8423-ef63-4772-99d7-1cca6e5d40a3',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [-3.1554286896428683, -7.532379306112865, -9.22359788787638, -3.854554691087193]}],
# ...

# %%
df
# Out:
#            A         B         C         D
# 0   0.855845  0.304247  0.148263  0.440381
# 1   0.991168 -0.414742 -0.855016  0.656566
# 2   1.736655 -0.322684 -0.660755 -0.640801
# 3   0.812633  0.444356  0.441561  0.302533
# 4  -0.984177  3.206725 -0.544054 -2.045357
# ..       ...       ...       ...       ...
# 95  0.686441  1.777911 -0.898918  0.252687
# 96  0.692718  1.028938 -0.059923  0.017716
# 97 -0.460625 -0.881843 -1.472172  1.077870
# 98  1.324927  1.153510 -0.448922  1.917004
# 99  0.286166 -0.796863  0.430403  0.776166
#
# [100 rows x 4 columns]

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="831461cb-6eba-4e3b-9f47-ebaffa3c8d37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("831461cb-6eba-4e3b-9f47-ebaffa3c8d37")) {
#                     Plotly.newPlot(
#                         '831461cb-6eba-4e3b-9f47-ebaffa3c8d37',
# ...

# %%
# 3D SURFACE PLOTS
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],
                    'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="99deddc9-2529-4130-ae2e-641a4df5a456" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("99deddc9-2529-4130-ae2e-641a4df5a456")) {
#                     Plotly.newPlot(
#                         '99deddc9-2529-4130-ae2e-641a4df5a456',
# ...

# %%
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="d6139fbb-193c-4a6b-b07b-d7f88b48ab22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d6139fbb-193c-4a6b-b07b-d7f88b48ab22")) {
#                     Plotly.newPlot(
#                         'd6139fbb-193c-4a6b-b07b-d7f88b48ab22',
# ...

# %%
df.iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="aa5f0bcf-bb92-48e0-a443-b124adc5b2a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aa5f0bcf-bb92-48e0-a443-b124adc5b2a9")) {
#                     Plotly.newPlot(
#                         'aa5f0bcf-bb92-48e0-a443-b124adc5b2a9',
# ...

# %%
#u can also turn them on and off from the label box

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="d8b94dc2-10c9-46a0-a1b2-1bd2a6185773" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d8b94dc2-10c9-46a0-a1b2-1bd2a6185773")) {
#                     Plotly.newPlot(
#                         'd8b94dc2-10c9-46a0-a1b2-1bd2a6185773',
# ...

# %%
#bubble plot

# %%
df.iplot(kind='bubble',x='A', y='B',size ='C')
# Out:
# <div>
#
#
#             <div id="4c2ec2eb-33b6-48c6-85b3-1d252422663f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4c2ec2eb-33b6-48c6-85b3-1d252422663f")) {
#                     Plotly.newPlot(
#                         '4c2ec2eb-33b6-48c6-85b3-1d252422663f',
# ...

# %%
#scattered matrix all columns must be numerical for this to work
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="26e43de6-1cde-4cb8-af52-a71f7f46c752" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("26e43de6-1cde-4cb8-af52-a71f7f46c752")) {
#                     Plotly.newPlot(
#                         '26e43de6-1cde-4cb8-af52-a71f7f46c752',
# ...
