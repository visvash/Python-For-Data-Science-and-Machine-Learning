# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
# take realistic situation

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize =(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df,hue='grade')

# %%
plt.figure(figsize =(12,8))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['bathrooms'])

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
sns.pairplot(df.drop(labels=['zipcode','id','date','lat','long','yr_built','yr_renovated','waterfront','view',],axis=1))

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='magma')

# %%
df.sort_values('price',ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.sort_values('bedrooms',ascending=False)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895   6/25/2014   640000.0        33       1.75         1620
# 8748   1773100755   8/21/2014   520000.0        11       3.00         3000
# 13301   627300145   8/14/2014  1150000.0        10       5.25         4590
# 19239  8812401450  12/29/2014   660000.0        10       3.00         2920
# 15147  5566100170  10/29/2014   650000.0        10       2.00         3610
# ...           ...         ...        ...       ...        ...          ...
# 12472  1172000150   8/29/2014   238000.0         1       1.00          530
# 13316  4356200120  10/23/2014   248000.0         1       1.00          790
# 7010    203100460   9/24/2014   400000.0         1       1.00          530
# 3578   1925069006   12/3/2014   355000.0         1       0.75          530
# 14373  7518503065   6/23/2014   335000.0         1       1.00          720
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.sort_values('price',ascending=True)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# ...           ...         ...        ...       ...        ...          ...
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
len(df)
# Out:
# 21597

# %%
bottom_99 = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=bottom_99,hue='price',
               edgecolor=None,alpha=0.2,palette='RdYlGn')

# %%
top_1 = df.sort_values('price',ascending=False).iloc[:216]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=top_1,hue='price',
               edgecolor=None,alpha=0.2,palette='RdYlGn')

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
plt.figure(figsize=(10,10))
sns.distplot(bottom_99['price'],bins=200,kde=False)

# %%
df= df.drop('id',axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year']=df['date'].apply(lambda date: date.year)
df['month']=df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'].plot()

# %%
df= df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X= df.drop('price',axis=1).values
y= df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train, y=y_train, 
          validation_data=(X_test,y_test),
          batch_size = 128,
          epochs=400
         )
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 3ms/step - loss: 430244364288.0000 - val_loss: 418944319488.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 1ms/step - loss: 429634977792.0000 - val_loss: 416887177216.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 1ms/step - loss: 421764202496.0000 - val_loss: 399098707968.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 1ms/step - loss: 382731485184.0000 - val_loss: 332543983616.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 1ms/step - loss: 281495666688.0000 - val_loss: 203986010112.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 1ms/step - loss: 155544403968.0000 - val_loss: 109592854528.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 103223992320.0000 - val_loss: 95376343040.0000
# Epoch 8/400
# ...

# %%
# part 3 PREDICTIONS

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302444e+11  4.189443e+11
# 1    4.296350e+11  4.168872e+11
# 2    4.217642e+11  3.990987e+11
# 3    3.827315e+11  3.325440e+11
# 4    2.814957e+11  2.039860e+11
# ..            ...           ...
# 395  2.873684e+10  2.661912e+10
# 396  2.871934e+10  2.659370e+10
# 397  2.872760e+10  2.657885e+10
# 398  2.869222e+10  2.652283e+10
# 399  2.864626e+10  2.653448e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 26534488550.144463

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 162894.1022570936

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 100264.42421995563

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# this evaluatuon is not too good
# avg price is 540,000 dollars & we get an error of 100,000 dollars

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7999438216329635

# %%
# nearly okay

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test, predictions)
plt.plot(y_test,y_test,'r')

# %%
single_house = df.drop('price',axis=1).iloc[0]
single_house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# Name: 0, dtype: float64

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
model.predict(single_house)
# Out:
# array([[284249.94]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
# EARLY STOPPING

# %%
#callbacks
